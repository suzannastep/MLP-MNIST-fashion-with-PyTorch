# %% [markdown]
# # imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from main import *
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import pickle

# %% [markdown]
# # visualize data

# %%
train_loader, validate_loader, test_loader = load_original_mnist_fashion(1000,10)
x,y = next(iter(train_loader))
plt.imshow(1-x[0][0],cmap='gray')
plt.title(y[0])
print(x.min(),x.max())
# Out:
# tensor(-0.4242) tensor(2.8215)

# %% [markdown]
# # read results

# %%
cd /net/projects/willettlab/sueparkinson/deeprelu/fashionMNIST
# Out:
# /net/projects/willettlab/sueparkinson/deeprelu/fashionMNIST

# %%
res = []
modelclasses = [ModelA,ModelB,ModelC,ModelD,ModelE,ModelF,ModelG,
                ModelA_middlelinear,ModelB_middlelinear,ModelC_middlelinear,ModelD_middlelinear,ModelE_middlelinear,ModelF_middlelinear,ModelG_middlelinear]
for model in modelclasses:
    modelres = {}

    #load model from state dict
    m = model(image_size=28 * 28, lr = 0)
    model_letter = m.name[6]
    filename = "_model_"+m.name[6]
    if len(m.name) > 7:
        ismiddlelinear = True
        filename += 'ml'
    else:
        ismiddlelinear = False
    print("loading",filename+"/model.pt onto",model)
    model_state_dict = torch.load(filename+"/model.pt")
    m.load_state_dict(model_state_dict)
    m.eval()

    #load pickle file for model
    try:
        with open(f"{filename}/model.pkl", "rb") as f:
            p = pickle.load(f)
    except EOFError as e:
        print(e)

    #save results for model into dictionary
    modelres["name"] = p.name[6]
    modelres["middlelinear"] = ismiddlelinear
    modelres["# hidden layers"] = 4 if (ismiddlelinear or p.name[6] > "D") else 2
    modelres["model sketch"] = p.modelsketch
    modelres["optimizer"] = str(p.optimizer)[:4]
    modelres["learning rate"] = p.lr
    modelres["epochs"] = len(p.train_accuracies)
    modelres["batch normalization"] = True if p.name[6] in "DG" else False
    modelres["dropout"] = True if p.name[6] in "CG" else False
    modelres["final train_accuracies"] = p.train_accuracies[-1]
    modelres["final train_loss"] = p.train_loss[-1]
    modelres["final validate_accuracies"] = p.validate_accuracies[-1]
    modelres["final validate_loss"] = p.validate_loss[-1]
    modelres["final test_accuracies"] = p.test_accuracies[-1]
    modelres["final test_loss"] = p.test_loss[-1]
    modelres["train_accuracies"] = p.train_accuracies
    modelres["train_loss"] = p.train_loss
    modelres["validate_accuracies"] = p.validate_accuracies
    modelres["validate_loss"] = p.validate_loss
    modelres["test_accuracies"] = p.test_accuracies
    modelres["test_loss"] = p.test_loss
    modelres["model for eval"] = m
    modelres["pickle file"] = p

    res.append(modelres)
res = pd.DataFrame(res)
# Out:
# loading _model_A/model.pt onto <class 'main.ModelA'>
# loading _model_B/model.pt onto <class 'main.ModelB'>
# loading _model_C/model.pt onto <class 'main.ModelC'>
# loading _model_D/model.pt onto <class 'main.ModelD'>
# loading _model_E/model.pt onto <class 'main.ModelE'>
# loading _model_F/model.pt onto <class 'main.ModelF'>
# loading _model_G/model.pt onto <class 'main.ModelG'>
# loading _model_Aml/model.pt onto <class 'main.ModelA_middlelinear'>
# loading _model_Bml/model.pt onto <class 'main.ModelB_middlelinear'>
# loading _model_Cml/model.pt onto <class 'main.ModelC_middlelinear'>
# loading _model_Dml/model.pt onto <class 'main.ModelD_middlelinear'>
# loading _model_Eml/model.pt onto <class 'main.ModelE_middlelinear'>
# loading _model_Fml/model.pt onto <class 'main.ModelF_middlelinear'>
# loading _model_Gml/model.pt onto <class 'main.ModelG_middlelinear'>

# %%
res
# Out:
#    name  middlelinear  # hidden layers  \
# 0     A         False                2
# 1     B         False                2
# 2     C         False                2
# 3     D         False                2
# 4     E         False                4
# 5     F         False                4
# 6     G         False                4
# 7     A          True                4
# 8     B          True                4
# 9     C          True                4
# 10    D          True                4
# 11    E          True                4
# 12    F          True                4
# 13    G          True                4
#
#                                          model sketch optimizer  \
# 0                         100 ReLU 50 ReLU 10 Softmax      SGD
# 1                         100 ReLU 50 ReLU 10 Softmax      Adam
# 2                         100 ReLU 50 ReLU 10 Softmax      Adam
# 3                         100 ReLU 50 ReLU 10 Softmax      Adam
# 4         128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax      SGD
# 5   128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 1...      Adam
# 6   512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 L...      SGD
# 7   100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      SGD
# 8   100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      Adam
# 9   100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      Adam
# 10  100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      Adam
# 11    128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax      SGD
# 12  128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 ...      Adam
# 13  512 LeakyReLU 256 Linear 128 Linear 64 LeakyRe...      Adam
#
#     learning rate  epochs  batch normalization  dropout  \
# 0          0.1200      19                False    False
# 1          0.0001      25                False    False
# 2          0.0001      26                False     True
# 3          0.0100      18                 True    False
# 4          0.1000      19                False    False
# 5          0.0010      21                False    False
# 6          0.0010      28                 True     True
# 7          0.1200      21                False    False
# 8          0.0001      19                False    False
# 9          0.0001      28                False     True
# 10         0.0100      15                 True    False
# 11         0.1000      17                False    False
# 12         0.0010      28                False    False
# 13         0.0010      22                 True     True
#
#     final train_accuracies  ...  final test_accuracies  final test_loss  \
# 0                90.209259  ...                  87.76         0.343438
# 1                84.562963  ...                  83.08         0.472084
# 2                82.187037  ...                  82.69         0.489232
# 3                93.794444  ...                  89.30         0.305813
# 4                90.238889  ...                  87.54         0.363651
# 5                41.794444  ...                  41.15         1.353921
# 6                93.807407  ...                  90.55         0.278975
# 7                91.083333  ...                  88.05         0.336193
# 8                83.720370  ...                  82.57         0.493052
# 9                83.014815  ...                  82.91         0.480683
# 10               93.862963  ...                  88.74         0.321612
# 11               90.400000  ...                  87.26         0.355611
# 12               85.700000  ...                  83.45         0.606598
# 13               93.438889  ...                  89.59         0.299082
#
#                                      train_accuracies  \
# 0   [75.63148148148149, 83.72962962962963, 85.4888...
# 1   [57.6, 76.96296296296296, 79.97222222222223, 8...
# 2   [47.99074074074074, 71.45185185185186, 75.6259...
# 3   [82.94814814814815, 86.99444444444444, 88.2166...
# 4   [46.67037037037037, 75.6462962962963, 80.35185...
# 5   [13.794444444444444, 20.36111111111111, 25.494...
# 6   [81.37407407407407, 86.1574074074074, 87.25555...
# 7   [70.11296296296297, 83.17037037037036, 85.1037...
# 8   [53.327777777777776, 72.52222222222223, 76.522...
# 9   [46.48888888888889, 68.46666666666667, 74.4907...
# 10  [82.70925925925926, 86.45, 87.74259259259259, ...
# 11  [58.65555555555556, 80.77037037037037, 83.7222...
# 12  [51.025925925925925, 65.32962962962964, 67.914...
# 13  [81.8962962962963, 85.90555555555555, 87.31851...
#
#                                            train_loss  \
# 0   [0.70908912619838, 0.45407364988327026, 0.4023...
# 1   [1.4265233975869638, 0.736211624428078, 0.6042...
# 2   [1.590676074133979, 0.8985561578538682, 0.7293...
# 3   [0.5022192527453104, 0.3561618208708586, 0.319...
# 4   [1.413590716821176, 0.6665502166748047, 0.5367...
# 5   [2.257743896766945, 1.9915629044991952, 1.8266...
# 6   [0.6707420018160785, 0.4027337857705575, 0.356...
# 7   [0.8299136508659081, 0.4659181646947507, 0.410...
# 8   [1.4386825359485766, 0.7773293250755028, 0.641...
# 9   [1.5426119843942148, 0.876640905380249, 0.7217...
# 10  [0.5121488563749526, 0.3727715864358125, 0.336...
# 11  [1.1013538994612517, 0.5326901833392955, 0.452...
# 12  [1.8545567581741897, 1.3727691824171278, 1.127...
# 13  [0.6639906242865103, 0.40794653791851465, 0.36...
#
#                                   validate_accuracies  \
# 0   [81.45, 84.6, 85.03333333333333, 85.95, 86.816...
# 1   [73.56666666666666, 78.35, 80.48333333333333, ...
# 2   [72.01666666666667, 77.76666666666667, 79.85, ...
# 3   [85.78333333333333, 87.81666666666666, 87.9833...
# 4   [68.51666666666667, 76.58333333333333, 80.5333...
# 5   [20.466666666666665, 20.716666666666665, 28.23...
# 6   [86.71666666666667, 87.16666666666667, 88.0333...
# 7   [80.46666666666667, 84.61666666666666, 83.7, 8...
# 8   [69.41666666666667, 75.81666666666666, 78.5166...
# 9   [69.01666666666667, 76.6, 79.1, 81.1, 82.4, 83...
# 10  [85.6, 86.58333333333333, 87.16666666666667, 8...
# 11  [75.86666666666666, 82.68333333333334, 83.1333...
# 12  [63.733333333333334, 67.45, 69.06666666666666,...
# 13  [85.3, 87.91666666666667, 88.41666666666667, 8...
#
#                                         validate_loss  \
# 0   [0.50438649670283, 0.4231002275149027, 0.40542...
# 1   [0.8704624525705973, 0.6505606899261475, 0.572...
# 2   [1.009055690765381, 0.7145502834320069, 0.6172...
# 3   [0.39923496993382773, 0.34062428283691404, 0.3...
# 4   [0.8111907316843668, 0.6157331250508626, 0.521...
# 5   [2.125641815185547, 1.8964965909322102, 1.7847...
# 6   [0.3975236808458964, 0.35741117000579836, 0.33...
# 7   [0.5468789812723795, 0.42298058811823525, 0.43...
# 8   [0.8908254661560059, 0.6822762422561646, 0.602...
# 9   [0.9138777726491293, 0.6835101858774821, 0.595...
# 10  [0.4034151927630107, 0.3721267348925273, 0.363...
# 11  [0.6663947941462199, 0.47854968245824175, 0.45...
# 12  [1.5554134991963704, 1.2352923380533853, 1.057...
# 13  [0.4306629180908203, 0.33973233493169147, 0.32...
#
#                                       test_accuracies  \
# 0   [80.74, 83.56, 84.22, 85.37, 85.97, 86.36, 86....
# 1   [73.05, 77.8, 79.93, 81.0, 81.73, 82.23, 82.54...
# 2   [71.52, 77.24, 79.05, 80.16, 80.83, 81.61, 82....
# 3   [84.55, 86.76, 86.91, 87.51, 86.96, 87.94, 88....
# 4   [68.83, 76.6, 80.22, 84.23, 84.55, 85.95, 85.6...
# 5   [20.64, 21.0, 28.23, 29.13, 36.37, 39.37, 40.2...
# 6   [85.02, 86.81, 86.99, 88.14, 88.26, 87.44, 88....
# 7   [79.14, 84.08, 83.27, 84.5, 86.09, 86.79, 85.9...
# 8   [68.14, 74.59, 76.83, 78.45, 80.11, 80.89, 81....
# 9   [69.2, 75.73, 78.03, 79.48, 80.47, 81.63, 81.9...
# 10  [85.32, 85.68, 85.88, 86.75, 86.96, 86.78, 87....
# 11  [76.7, 82.35, 82.82, 84.64, 84.93, 85.68, 85.6...
# 12  [63.33, 66.38, 68.43, 75.19, 76.85, 78.04, 79....
# 13  [83.76, 87.03, 86.65, 87.55, 88.0, 88.28, 88.0...
#
#                                             test_loss  \
# 0   [0.5265525437355042, 0.4508635232925415, 0.436...
# 1   [0.8848914382934571, 0.6649954626083374, 0.587...
# 2   [1.0194674549102782, 0.7268041358947754, 0.632...
# 3   [0.42663482093811034, 0.3669264856338501, 0.36...
# 4   [0.8184945423126221, 0.6282572961807251, 0.540...
# 5   [2.128998173522949, 1.9027229949951172, 1.7906...
# 6   [0.42078506507873537, 0.3671038681983948, 0.35...
# 7   [0.5714997831344605, 0.44656249208450316, 0.45...
# 8   [0.9126004863739013, 0.7034542440414429, 0.621...
# 9   [0.9318781646728516, 0.7086837749481201, 0.625...
# 10  [0.4134256743431091, 0.3945632009506226, 0.384...
# 11  [0.6603152938842773, 0.4934155233383179, 0.474...
# 12  [1.56222816696167, 1.242635814666748, 1.064789...
# 13  [0.46718195533752443, 0.37024264516830446, 0.3...
#
#                                        model for eval  \
# 0   ModelA(\n  (fc0): Linear(in_features=784, out_...
# 1   ModelB(\n  (fc0): Linear(in_features=784, out_...
# 2   ModelC(\n  (fc0): Linear(in_features=784, out_...
# 3   ModelD(\n  (fc0): Linear(in_features=784, out_...
# 4   ModelE(\n  (fc0): Linear(in_features=784, out_...
# 5   ModelF(\n  (fc0): Linear(in_features=784, out_...
# 6   ModelG(\n  (batch_norm_0): BatchNorm1d(784, ep...
# 7   ModelA_middlelinear(\n  (fc0): Linear(in_featu...
# 8   ModelB_middlelinear(\n  (fc0): Linear(in_featu...
# 9   ModelC_middlelinear(\n  (fc0): Linear(in_featu...
# 10  ModelD_middlelinear(\n  (fc0): Linear(in_featu...
# 11  ModelE_middlelinear(\n  (fc0): Linear(in_featu...
# 12  ModelF_middlelinear(\n  (fc0): Linear(in_featu...
# 13  ModelG_middlelinear(\n  (batch_norm_0): BatchN...
#
#                                           pickle file
# 0   ModelA(\n  (fc0): Linear(in_features=784, out_...
# 1   ModelB(\n  (fc0): Linear(in_features=784, out_...
# 2   ModelC(\n  (fc0): Linear(in_features=784, out_...
# 3   ModelD(\n  (fc0): Linear(in_features=784, out_...
# 4   ModelE(\n  (fc0): Linear(in_features=784, out_...
# 5   ModelF(\n  (fc0): Linear(in_features=784, out_...
# 6   ModelG(\n  (batch_norm_0): BatchNorm1d(784, ep...
# 7   ModelA_middlelinear(\n  (fc0): Linear(in_featu...
# 8   ModelB_middlelinear(\n  (fc0): Linear(in_featu...
# 9   ModelC_middlelinear(\n  (fc0): Linear(in_featu...
# 10  ModelD_middlelinear(\n  (fc0): Linear(in_featu...
# 11  ModelE_middlelinear(\n  (fc0): Linear(in_featu...
# 12  ModelF_middlelinear(\n  (fc0): Linear(in_featu...
# 13  ModelG_middlelinear(\n  (batch_norm_0): BatchN...
#
# [14 rows x 23 columns]

# %%
res.columns
# Out:
# Index(['name', 'middlelinear', '# hidden layers', 'model sketch', 'optimizer',
#        'learning rate', 'epochs', 'batch normalization', 'dropout',
#        'final train_accuracies', 'final train_loss',
#        'final validate_accuracies', 'final validate_loss',
#        'final test_accuracies', 'final test_loss', 'train_accuracies',
#        'train_loss', 'validate_accuracies', 'validate_loss', 'test_accuracies',
#        'test_loss', 'model for eval', 'pickle file'],
#       dtype='object')

# %% [markdown]
# # pairwise distances

# %%
def pairwise_L2_distance(f1,f2,d,domain_lb=-0.5,domain_ub=0.5,numsamples=2000,seed=892):
    logging.info(f"{f1,f2,domain_lb,domain_ub,numsamples,seed}")
    np.random.seed(seed)
    #create samples from U[domainlb,domainub]^d 
    samplesX = np.random.rand(d,numsamples).astype(np.float32) #distributed as U[0,1]^d
    domain_size = domain_ub - domain_lb
    samplesX *= domain_size #distributed as U[0,domain_ub - domain_lb]^d
    samplesX += domain_lb #distributed as U[domain_lb,domain_ub]^d
    samplesX = torch.from_numpy(samplesX).T # move to device
    #compute E[(f1(x) - f2(x))^2]
    with torch.no_grad():
        f1eval = f1(samplesX)
        f2eval = f2(samplesX)
        distance = nn.functional.mse_loss(f1eval,f2eval).item()
    return distance

# %%
for m1 in res["model for eval"]:
    dist_from_m1 = []
    for m2 in res["model for eval"]:
        dist = pairwise_L2_distance(m1,m2,d=28*28,domain_lb=-0.4242,domain_ub=2.8215)
        dist_from_m1.append(dist)
    res["dist from "+m1.name] = dist_from_m1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 4
#       2 dist_from_m1 = []
#       3 for m2 in res["model for eval"]:
# ----> 4     dist = pairwise_L2_distance(m1,m2,d=28*28,domain_lb=-0.4242,domain_ub=2.8215)
#       5     dist_from_m1.append(dist)
#       6 res["dist from "+m1.name] = dist_from_m1
#
# Cell In[80], line 5, in pairwise_L2_distance(f1, f2, d, domain_lb, domain_ub, numsamples, seed)
#       3 np.random.seed(seed)
#       4 #create samples from U[domainlb,domainub]^d
# ----> 5 samplesX = np.random.rand(d,numsamples).astype(np.float32) #distributed as U[0,1]^d
#       6 domain_size = domain_ub - domain_lb
#       7 samplesX *= domain_size #distributed as U[0,domain_ub - domain_lb]^d
#
# KeyboardInterrupt:

# %%
res
# Out:
#    name  middlelinear  # hidden layers  \
# 0     A         False                2
# 1     B         False                2
# 2     C         False                2
# 3     D         False                2
# 4     E         False                4
# 5     F         False                4
# 6     G         False                4
# 7     A          True                4
# 8     B          True                4
# 9     C          True                4
# 10    D          True                4
# 11    E          True                4
# 12    F          True                4
# 13    G          True                4
#
#                                          model sketch optimizer  \
# 0                         100 ReLU 50 ReLU 10 Softmax      SGD
# 1                         100 ReLU 50 ReLU 10 Softmax      Adam
# 2                         100 ReLU 50 ReLU 10 Softmax      Adam
# 3                         100 ReLU 50 ReLU 10 Softmax      Adam
# 4         128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax      SGD
# 5   128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 1...      Adam
# 6   512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 L...      SGD
# 7   100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      SGD
# 8   100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      Adam
# 9   100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      Adam
# 10  100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax      Adam
# 11    128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax      SGD
# 12  128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 ...      Adam
# 13  512 LeakyReLU 256 Linear 128 Linear 64 LeakyRe...      Adam
#
#     learning rate  epochs  batch normalization  dropout  \
# 0          0.1200      19                False    False
# 1          0.0001      25                False    False
# 2          0.0001      26                False     True
# 3          0.0100      18                 True    False
# 4          0.1000      19                False    False
# 5          0.0010      21                False    False
# 6          0.0010      28                 True     True
# 7          0.1200      21                False    False
# 8          0.0001      19                False    False
# 9          0.0001      28                False     True
# 10         0.0100      15                 True    False
# 11         0.1000      17                False    False
# 12         0.0010      28                False    False
# 13         0.0010      22                 True     True
#
#     final train_accuracies  ...  dist from Model E  dist from Model F  \
# 0                90.209259  ...           3.028375           9.887032
# 1                84.562963  ...           3.881537           9.907887
# 2                82.187037  ...           4.053549          11.438959
# 3                93.794444  ...          36.551445          42.379627
# 4                90.238889  ...           0.000000           9.094872
# 5                41.794444  ...           9.094872           0.000000
# 6                93.807407  ...          25.085051          30.883205
# 7                91.083333  ...           4.185145          12.504599
# 8                83.720370  ...           3.932406           6.976528
# 9                83.014815  ...           4.121931           9.911285
# 10               93.862963  ...          48.133755          52.554424
# 11               90.400000  ...           3.859563          11.188073
# 12               85.700000  ...           3.180861           5.977510
# 13               93.438889  ...          34.247295          36.208397
#
#     dist from Model G  dist from Model A middle linear  \
# 0           23.190546                         2.124603
# 1           31.814316                         3.026758
# 2           35.860741                         3.982692
# 3            8.523553                        31.839481
# 4           25.085051                         4.185145
# 5           30.883205                        12.504599
# 6            0.000000                        22.494467
# 7           22.494467                         0.000000
# 8           31.596951                         3.844558
# 9           35.688301                         3.703805
# 10          18.308582                        43.374214
# 11          28.705969                         2.496665
# 12          30.017290                         4.289124
# 13           7.808590                        31.365650
#
#     dist from Model B middle linear dist from Model C middle linear  \
# 0                          4.561251                        4.261119
# 1                          0.945977                        0.385426
# 2                          1.450567                        0.353883
# 3                         43.375820                       48.085320
# 4                          3.932406                        4.121931
# 5                          6.976528                        9.911285
# 6                         31.596951                       35.688301
# 7                          3.844558                        3.703805
# 8                          0.000000                        0.849871
# 9                          0.849871                        0.000000
# 10                        57.317108                       61.721920
# 11                         2.266091                        2.034342
# 12                         2.763921                        2.651760
# 13                        42.225204                       46.897938
#
#    dist from Model D middle linear dist from Model E middle linear  \
# 0                        40.798141                        3.567519
# 1                        57.257923                        2.076630
# 2                        63.655479                        2.028746
# 3                        14.087756                       39.116764
# 4                        48.133755                        3.859563
# 5                        52.554424                       11.188073
# 6                        18.308582                       28.705969
# 7                        43.374214                        2.496665
# 8                        57.317108                        2.266091
# 9                        61.721920                        2.034342
# 10                        0.000000                       53.493458
# 11                       53.493458                        0.000000
# 12                       52.164944                        3.228399
# 13                       13.190225                       38.860195
#
#    dist from Model F middle linear dist from Model G middle linear
# 0                         2.585584                       29.949963
# 1                         3.054127                       43.059952
# 2                         3.146912                       48.043976
# 3                        40.104923                        8.468133
# 4                         3.180861                       34.247295
# 5                         5.977510                       36.208397
# 6                        30.017290                        7.808590
# 7                         4.289124                       31.365650
# 8                         2.763921                       42.225204
# 9                         2.651760                       46.897938
# 10                       52.164944                       13.190225
# 11                        3.228399                       38.860195
# 12                        0.000000                       37.393204
# 13                       37.393204                        0.000000
#
# [14 rows x 37 columns]

# %%
dist_pivot = res.pivot_table(values=[
        'dist from Model E', 'dist from Model F', 'dist from Model G',
        'dist from Model E middle linear', 'dist from Model F middle linear',
        'dist from Model G middle linear'],
                index=('name','middlelinear','batch normalization','dropout'))

# %%
dist_pivot
# Out:
#                                                dist from Model E  \
# name middlelinear batch normalization dropout
# A    False        False               False             3.028375
#      True         False               False             4.185145
# B    False        False               False             3.881537
#      True         False               False             3.932406
# C    False        False               True              4.053549
#      True         False               True              4.121931
# D    False        True                False            36.551445
#      True         True                False            48.133755
# E    False        False               False             0.000000
#      True         False               False             3.859563
# F    False        False               False             9.094872
#      True         False               False             3.180861
# G    False        True                True             25.085051
#      True         True                True             34.247295
#
#                                                dist from Model E middle linear  \
# name middlelinear batch normalization dropout
# A    False        False               False                           3.567519
#      True         False               False                           2.496665
# B    False        False               False                           2.076630
#      True         False               False                           2.266091
# C    False        False               True                            2.028746
#      True         False               True                            2.034342
# D    False        True                False                          39.116764
#      True         True                False                          53.493458
# E    False        False               False                           3.859563
#      True         False               False                           0.000000
# F    False        False               False                          11.188073
#      True         False               False                           3.228399
# G    False        True                True                           28.705969
#      True         True                True                           38.860195
#
#                                                dist from Model F  \
# name middlelinear batch normalization dropout
# A    False        False               False             9.887032
#      True         False               False            12.504599
# B    False        False               False             9.907887
#      True         False               False             6.976528
# C    False        False               True             11.438959
#      True         False               True              9.911285
# D    False        True                False            42.379627
#      True         True                False            52.554424
# E    False        False               False             9.094872
#      True         False               False            11.188073
# F    False        False               False             0.000000
#      True         False               False             5.977510
# G    False        True                True             30.883205
#      True         True                True             36.208397
#
#                                                dist from Model F middle linear  \
# name middlelinear batch normalization dropout
# A    False        False               False                           2.585584
#      True         False               False                           4.289124
# B    False        False               False                           3.054127
#      True         False               False                           2.763921
# C    False        False               True                            3.146912
#      True         False               True                            2.651760
# D    False        True                False                          40.104923
#      True         True                False                          52.164944
# E    False        False               False                           3.180861
#      True         False               False                           3.228399
# F    False        False               False                           5.977510
#      True         False               False                           0.000000
# G    False        True                True                           30.017290
#      True         True                True                           37.393204
#
#                                                dist from Model G  \
# name middlelinear batch normalization dropout
# A    False        False               False            23.190546
#      True         False               False            22.494467
# B    False        False               False            31.814316
#      True         False               False            31.596951
# C    False        False               True             35.860741
#      True         False               True             35.688301
# D    False        True                False             8.523553
#      True         True                False            18.308582
# E    False        False               False            25.085051
#      True         False               False            28.705969
# F    False        False               False            30.883205
#      True         False               False            30.017290
# G    False        True                True              0.000000
#      True         True                True              7.808590
#
#                                                dist from Model G middle linear
# name middlelinear batch normalization dropout
# A    False        False               False                          29.949963
#      True         False               False                          31.365650
# B    False        False               False                          43.059952
#      True         False               False                          42.225204
# C    False        False               True                           48.043976
#      True         False               True                           46.897938
# D    False        True                False                           8.468133
#      True         True                False                          13.190225
# E    False        False               False                          34.247295
#      True         False               False                          38.860195
# F    False        False               False                          36.208397
#      True         False               False                          37.393204
# G    False        True                True                            7.808590
#      True         True                True                            0.000000

# %%
dist_pivot.loc[:,"dist from Model E"].plot.barh()
# Out:
# <Axes: ylabel='name,middlelinear,batch normalization,dropout'>

# %%
dist_pivot.loc[:,"dist from Model G"].plot.barh()
# Out:
# <Axes: ylabel='name,middlelinear,batch normalization,dropout'>

# %%
newdists = dist_pivot.copy()
newdists[newdists == 0] = np.inf
newdists.min()
# Out:
# dist from Model E                  3.028375
# dist from Model E middle linear    2.028746
# dist from Model F                  5.977510
# dist from Model F middle linear    2.585584
# dist from Model G                  7.808590
# dist from Model G middle linear    7.808590
# dtype: float64

# %% [markdown]
# # create table of results

# %%
res.pivot_table(values=['final train_loss', 'final train_accuracies',
                        'final validate_loss', 'final validate_accuracies',
                        'final test_accuracies', 'final test_loss'],
                index=('name','middlelinear','model sketch'))
# Out:
#                                                                       final test_accuracies  \
# name middlelinear model sketch
# A    False        100 ReLU 50 ReLU 10 Softmax                                         87.76
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   88.05
# B    False        100 ReLU 50 ReLU 10 Softmax                                         83.08
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   82.57
# C    False        100 ReLU 50 ReLU 10 Softmax                                         82.69
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   82.91
# D    False        100 ReLU 50 ReLU 10 Softmax                                         89.30
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   88.74
# E    False        128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax                         87.54
#      True         128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax                     87.26
# F    False        128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 10...                  41.15
#      True         128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 S...                  83.45
# G    False        512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 Le...                  90.55
#      True         512 LeakyReLU 256 Linear 128 Linear 64 LeakyReL...                  89.59
#
#                                                                       final test_loss  \
# name middlelinear model sketch
# A    False        100 ReLU 50 ReLU 10 Softmax                                0.343438
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax          0.336193
# B    False        100 ReLU 50 ReLU 10 Softmax                                0.472084
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax          0.493052
# C    False        100 ReLU 50 ReLU 10 Softmax                                0.489232
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax          0.480683
# D    False        100 ReLU 50 ReLU 10 Softmax                                0.305813
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax          0.321612
# E    False        128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax                0.363651
#      True         128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax            0.355611
# F    False        128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 10...         1.353921
#      True         128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 S...         0.606598
# G    False        512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 Le...         0.278975
#      True         512 LeakyReLU 256 Linear 128 Linear 64 LeakyReL...         0.299082
#
#                                                                       final train_accuracies  \
# name middlelinear model sketch
# A    False        100 ReLU 50 ReLU 10 Softmax                                      90.209259
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                91.083333
# B    False        100 ReLU 50 ReLU 10 Softmax                                      84.562963
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                83.720370
# C    False        100 ReLU 50 ReLU 10 Softmax                                      82.187037
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                83.014815
# D    False        100 ReLU 50 ReLU 10 Softmax                                      93.794444
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                93.862963
# E    False        128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax                      90.238889
#      True         128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax                  90.400000
# F    False        128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 10...               41.794444
#      True         128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 S...               85.700000
# G    False        512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 Le...               93.807407
#      True         512 LeakyReLU 256 Linear 128 Linear 64 LeakyReL...               93.438889
#
#                                                                       final train_loss  \
# name middlelinear model sketch
# A    False        100 ReLU 50 ReLU 10 Softmax                                 0.268567
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax           0.243428
# B    False        100 ReLU 50 ReLU 10 Softmax                                 0.441018
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax           0.460907
# C    False        100 ReLU 50 ReLU 10 Softmax                                 0.504397
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax           0.488265
# D    False        100 ReLU 50 ReLU 10 Softmax                                 0.172951
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax           0.166844
# E    False        128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax                 0.268805
#      True         128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax             0.263389
# F    False        128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 10...          1.319286
#      True         128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 S...          0.560395
# G    False        512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 Le...          0.165143
#      True         512 LeakyReLU 256 Linear 128 Linear 64 LeakyReL...          0.176405
#
#                                                                       final validate_accuracies  \
# name middlelinear model sketch
# A    False        100 ReLU 50 ReLU 10 Softmax                                         88.566667
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   88.950000
# B    False        100 ReLU 50 ReLU 10 Softmax                                         84.333333
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   83.550000
# C    False        100 ReLU 50 ReLU 10 Softmax                                         84.000000
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   84.733333
# D    False        100 ReLU 50 ReLU 10 Softmax                                         90.566667
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax                   90.000000
# E    False        128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax                         89.250000
#      True         128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax                     88.083333
# F    False        128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 10...                  40.700000
#      True         128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 S...                  84.350000
# G    False        512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 Le...                  91.066667
#      True         512 LeakyReLU 256 Linear 128 Linear 64 LeakyReL...                  91.266667
#
#                                                                       final validate_loss
# name middlelinear model sketch
# A    False        100 ReLU 50 ReLU 10 Softmax                                    0.314253
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax              0.309240
# B    False        100 ReLU 50 ReLU 10 Softmax                                    0.450412
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax              0.472192
# C    False        100 ReLU 50 ReLU 10 Softmax                                    0.465508
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax              0.443294
# D    False        100 ReLU 50 ReLU 10 Softmax                                    0.283202
#      True         100 ReLU 100 Linear 100 Linear 50 ReLU 10 Softmax              0.305008
# E    False        128 ReLU 64 ReLU 10 ReLU 10 ReLU 10 Softmax                    0.311269
#      True         128 ReLU 64 Linear 10 Linear 10 ReLU 10 Softmax                0.330970
# F    False        128 Sigmoid 64 Sigmoid 10 Sigmoid 10 Sigmoid 10...             1.352657
#      True         128 Sigmoid 64 Linear 10 Linear 10 Sigmoid 10 S...             0.597748
# G    False        512 LeakyReLU 256 LeakyReLU 128 LeakyReLU 64 Le...             0.267932
#      True         512 LeakyReLU 256 Linear 128 Linear 64 LeakyReL...             0.246604

# %%
piv = res.pivot_table(values=['final train_loss', 'final train_accuracies',
                        'final validate_loss', 'final validate_accuracies',
                        'final test_accuracies', 'final test_loss'],
                index=('name','middlelinear'))
piv
# Out:
#                    final test_accuracies  final test_loss  \
# name middlelinear
# A    False                         87.76         0.343438
#      True                          88.05         0.336193
# B    False                         83.08         0.472084
#      True                          82.57         0.493052
# C    False                         82.69         0.489232
#      True                          82.91         0.480683
# D    False                         89.30         0.305813
#      True                          88.74         0.321612
# E    False                         87.54         0.363651
#      True                          87.26         0.355611
# F    False                         41.15         1.353921
#      True                          83.45         0.606598
# G    False                         90.55         0.278975
#      True                          89.59         0.299082
#
#                    final train_accuracies  final train_loss  \
# name middlelinear
# A    False                      90.209259          0.268567
#      True                       91.083333          0.243428
# B    False                      84.562963          0.441018
#      True                       83.720370          0.460907
# C    False                      82.187037          0.504397
#      True                       83.014815          0.488265
# D    False                      93.794444          0.172951
#      True                       93.862963          0.166844
# E    False                      90.238889          0.268805
#      True                       90.400000          0.263389
# F    False                      41.794444          1.319286
#      True                       85.700000          0.560395
# G    False                      93.807407          0.165143
#      True                       93.438889          0.176405
#
#                    final validate_accuracies  final validate_loss
# name middlelinear
# A    False                         88.566667             0.314253
#      True                          88.950000             0.309240
# B    False                         84.333333             0.450412
#      True                          83.550000             0.472192
# C    False                         84.000000             0.465508
#      True                          84.733333             0.443294
# D    False                         90.566667             0.283202
#      True                          90.000000             0.305008
# E    False                         89.250000             0.311269
#      True                          88.083333             0.330970
# F    False                         40.700000             1.352657
#      True                          84.350000             0.597748
# G    False                         91.066667             0.267932
#      True                          91.266667             0.246604

# %%
for metric in ['final train_loss', 'final train_accuracies',
                        'final validate_loss', 'final validate_accuracies',
                        'final test_accuracies', 'final test_loss']:
        res.pivot_table(values=metric,
                index=('name','middlelinear')).plot.barh()

# %%
res.pivot_table(values=['final train_loss',
                        'final validate_loss',
                        'final test_accuracies', 'final test_loss'],
                index=('name','middlelinear','model sketch'))
